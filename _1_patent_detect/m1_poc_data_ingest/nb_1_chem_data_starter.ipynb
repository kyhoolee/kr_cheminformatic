# %%
import pandas as pd

# %%
df = pd.read_pickle("./outputs/chembl36_clean.pkl")
print(df.head())
print("\nRows:", len(df), "Unique InChIKey:", df['inchikey'].nunique())
print("\nMissing FP:", df['fp_b64'].isna().sum())
# Out:
#       chembl_id                                   canonical_smiles  \
# 0  CHEMBL153534                       Cc1cc(-c2csc(N=C(N)N)n2)cn1C
# 1  CHEMBL440060  CC[C@H](C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@@H...
# 2  CHEMBL440245  CCCC[C@@H]1NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(...
# 3  CHEMBL440249  CC(C)C[C@@H]1NC(=O)CNC(=O)[C@H](c2ccc(O)cc2)NC...
# 4  CHEMBL405398             Brc1cccc(Nc2ncnc3ccncc23)c1NCCN1CCOCC1
#
#                       inchikey  \
# 0  MFRNFCWYPYSFQQ-UHFFFAOYSA-N
# 1  RSEQNZQKBMRQNM-VRGFNVLHSA-N
# 2  FTKBTEIKPOYCEX-OZSLQWTKSA-N
# 3  UYSXXKGACMHPIM-KFGDMSGDSA-N
# 4  VDSXZXJEWIWBCG-UHFFFAOYSA-N
#
#                                               fp_b64
# 0  AAgEAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAA...
# 1  AggAAAECCEAAgAEAAAAwAAAQCQAQAAAAIgAgQQgQBAAAAA...
# 2  AgAAAAEgCAAAgAEAAAAgAAAQCQCAAAAAAEAgQAAQAAAAAA...
# 3  AgQACAACCAAAAEMAAAAgAAgRCAAAAAAAIAAAQAgAAKAAAA...
# 4  AAAAAAAAAAYAAAEAAAAAAAAAAAAAAAQAAAAAAAAAAAAAAA...
#
# Rows: 4999 Unique InChIKey: 4999
#
# ...

# %%
df.head()
# Out:
#       chembl_id                                   canonical_smiles  \
# 0  CHEMBL153534                       Cc1cc(-c2csc(N=C(N)N)n2)cn1C
# 1  CHEMBL440060  CC[C@H](C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@@H...
# 2  CHEMBL440245  CCCC[C@@H]1NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(...
# 3  CHEMBL440249  CC(C)C[C@@H]1NC(=O)CNC(=O)[C@H](c2ccc(O)cc2)NC...
# 4  CHEMBL405398             Brc1cccc(Nc2ncnc3ccncc23)c1NCCN1CCOCC1
#
#                       inchikey  \
# 0  MFRNFCWYPYSFQQ-UHFFFAOYSA-N
# 1  RSEQNZQKBMRQNM-VRGFNVLHSA-N
# 2  FTKBTEIKPOYCEX-OZSLQWTKSA-N
# 3  UYSXXKGACMHPIM-KFGDMSGDSA-N
# 4  VDSXZXJEWIWBCG-UHFFFAOYSA-N
#
#                                               fp_b64
# 0  AAgEAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAA...
# 1  AggAAAECCEAAgAEAAAAwAAAQCQAQAAAAIgAgQQgQBAAAAA...
# 2  AgAAAAEgCAAAgAEAAAAgAAAQCQCAAAAAAEAgQAAQAAAAAA...
# 3  AgQACAACCAAAAEMAAAAgAAgRCAAAAAAAIAAAQAgAAKAAAA...
# 4  AAAAAAAAAAYAAAEAAAAAAAAAAAAAAAQAAAAAAAAAAAAAAA...
